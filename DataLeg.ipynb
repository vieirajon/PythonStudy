# %%
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib import rcParams

import seaborn as sns

# %matplotlib inline 
rcParams['figure.figsize'] = 8, 4
sns.set_style('whitegrid')

caminho = 'C:\\Users\\Pichau\\Downloads\\arquivos_de_exercicios_python_para_ciencia_dados_basico\\dados\\mtcars.csv'
carros = pd.read_csv(caminho)
carros.columns = ['nomes', 'mpg', 'syl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
mpg = carros['mpg']

x = range(1,10)
y = [1, 2, 3, 4, .5, 4, 2, 3, 1]
plt.bar (x, y)
plt.xlabel('Título do eixo X')
plt.ylabel('Título do eixo Y')
# Out:
# Text(0, 0.5, 'Título do eixo Y')

# %%
import matplotlib.patches as mpatches

plt.plot(mpg)
plt.xlabel('Nome dos Carros')
plt.ylabel('milhas/galão')
plt.title('Consumo de Gasolina')
plt.xticks(mpg.index, carros.nomes, rotation=45)
plt.rcParams['figure.figsize'] = (25,7)

legenda = mpatches.Patch(label='mpg')
plt.legend(handles=[legenda])

# %%
mpg.max()
# Out:
# 33.9

# %%
plt.plot(mpg)
plt.xlabel('Nome dos Carros')
plt.ylabel('milhas/galão')
plt.title('Consumo de Gasolina')
plt.xticks(mpg.index, carros.nomes, rotation=45)
plt.rcParams['figure.figsize'] = (25,7)

legenda = mpatches.Patch(label='mpg')
plt.legend(handles=[legenda])
plt.annotate('Toyota Corolla', xy= (19, 33.9), xytext=(21, 33), arrowprops=dict(facecolor='black', shrink= 0.05) )
# Out:
# Text(21, 33, 'Toyota Corolla')
